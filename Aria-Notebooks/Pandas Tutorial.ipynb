# %%
df = pd.read_csv(r'C:\Users\Aria Jadhav\Downloads\developer_survey_2020\survey_results_public.csv', index_col ="Respondent")

# %%
import pandas as pd

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.info
# Out:
# <bound method DataFrame.info of        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
pd.set_option('display.max_columns',61)
pd.set_option('display.max_rows',61)
#reload df to see all columns being displayed

# %%
schema_df = pd.read_csv(r'C:\Users\Aria Jadhav\Downloads\developer_survey_2020\survey_results_schema.csv', index_col="Column")

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc["JobFactors", "QuestionText"]
# Out:
# 'Imagine that you are deciding between two job offers with the same compensation, benefits, and location. Of the following factors, which 3 are MOST important to you?'

# %%
schema_df.sort_index

#sorting alphabetically
# Out:
# <bound method DataFrame.sort_index of                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# ...

# %%
high_salary = (df['ConvertedComp']> 7000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# 12                             I am a developer by profession       No  49.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# ...                                                       ...      ...   ...
# 65611                          I am a developer by profession       No   NaN
# 65617                          I am a developer by profession      Yes   NaN
# 65625                          I am a developer by profession      Yes   NaN
# 65630                          I am a developer by profession      Yes   NaN
# 65631                          I am a developer by profession      Yes   NaN
#
# ...

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                   LanguageWorkedWith  ConvertedComp
# Respondent
# 8            United States                           Python;SQL       116000.0
# 10          United Kingdom  HTML/CSS;Java;JavaScript;Python;SQL        32315.0
# 11          United Kingdom                  C#;JavaScript;Swift        40070.0
# 12                   Spain                  HTML/CSS;JavaScript        14268.0
# 13             Netherlands                  C;JavaScript;Python        38916.0
# ...                    ...                                  ...            ...
# 65611              Denmark                                  NaN        38208.0
# 65617              Germany                                  NaN       129718.0
# 65625             Colombia                                  NaN        19428.0
# 65630                Chile                                  NaN        15048.0
# 65631                Japan                                  NaN        38759.0
#
# ...

# %%
countries = ['United States', 'India', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
filt
# Out:
# Respondent
# 1         True
# 2        False
# 3        False
# 4        False
# 5         True
#          ...
# 64858     True
# 64867    False
# 64898    False
# 64925    False
# 65112    False
# Name: Country, Length: 64461, dtype: bool

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 1              Germany
# 5        United States
# 6              Germany
# 7                India
# 8        United States
#              ...
# 62834           Canada
# 62954            India
# 63077    United States
# 64236            India
# 64858    United States
# Name: Country, Length: 26953, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
#                                ...
# 64858                                                  NaN
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                  NaN
# 64925                                             HTML/CSS
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
filt_1 = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt_1,'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object
