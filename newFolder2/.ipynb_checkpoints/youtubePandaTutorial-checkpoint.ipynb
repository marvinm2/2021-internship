# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.info
# Out:
# <bound method DataFrame.info of        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
df['Hobbyist'].head(10)
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# 5     No
# 6    Yes
# 7    Yes
# 8     No
# 9    Yes
# Name: Hobbyist, dtype: object

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %% [markdown]
# Use loc to use the labels, use iloc to just use integers.

# %%
df.loc[1, 'Hobbyist']
# Out:
# 'No'

# %% [markdown]
# Don't put it in brackets

# %%
df.loc[0:5, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# 5     No
# Name: Hobbyist, dtype: object

# %%
df.loc[0:5, 'Hobbyist':'Country']
# Out:
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes   NaN         13  Monthly        NaN            NaN
# 1       No   NaN         19      NaN        NaN            NaN
# 2      Yes   NaN         15      NaN        NaN            NaN
# 3      Yes  25.0         18      NaN        NaN            NaN
# 4      Yes  31.0         16      NaN        NaN            NaN
# 5       No   NaN         14      NaN        NaN            NaN
#
#               Country
# 0             Germany
# 1      United Kingdom
# 2  Russian Federation
# 3             Albania
# 4       United States
# 5             Germany

# %%
schema_df.set_index('Column', inplace=True)

# %% [markdown]
# if you don't do inplace then it won't permanently change. Also by doing this the ID is now column and not just auto generated integers form 0 to 61

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['OpSys', 'QuestionText']
# Out:
# 'What is the primary operating system in which you work?'

# %%
filt = (df['Hobbyist'] == 'Yes')

# %% [markdown]
# fun way to make filters. But you can also put the filter inside it automatically. df[df['Hobbyist] == 'Yes'] .
#
# This is hard to read so not recommended. Also you can add stuff to filter with and operator and or operator. & and |

# %%
df[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 6               7                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df['LanguageWorkedWith'].str.contains('Python', na=False)
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 64456    False
# 64457     True
# 64458    False
# 64459    False
# 64460    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.sort_values(by='SalaryUSD', ascending=False)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 33134       33254                     I am a developer by profession       No
# 4459         4475                     I am a developer by profession      Yes
# 46638       47615                     I am a developer by profession      Yes
# 46702       47680  I am not primarily a developer, but I write co...       No
# 58811       59974  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df['SalaryUSD'].nlargest(25)
# Out:
# 121     2000000.0
# 123     2000000.0
# 191     2000000.0
# 663     2000000.0
# 697     2000000.0
# 722     2000000.0
# 816     2000000.0
# 982     2000000.0
# 1018    2000000.0
# 1032    2000000.0
# 1113    2000000.0
# 1124    2000000.0
# 1188    2000000.0
# 1290    2000000.0
# 1339    2000000.0
# 1407    2000000.0
# 1478    2000000.0
# 1581    2000000.0
# 1616    2000000.0
# 1621    2000000.0
# 1784    2000000.0
# 1965    2000000.0
# 2084    2000000.0
# 2126    2000000.0
# 2491    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Respondent     32231.0
# Age               29.0
# CompTotal      63000.0
# SalaryUSD      54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe() #50% is median ofc
# Out:
#          Respondent           Age      CompTotal     SalaryUSD   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242  1.037561e+05     40.782174
# std    18967.442360      9.585392            inf  2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05  9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %% [markdown]
# use normalize for percentage

# %%
df['EdLevel'].value_counts(normalize=True)
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.462155
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.228309
# Some college/university study without earning a degree                                0.126047
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.083074
# Associate degree (A.A., A.S., etc.)                                                   0.032091
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.029427
# Primary/elementary school                                                             0.016385
# Professional degree (JD, MD, etc.)                                                    0.013930
# I never completed any formal education                                                0.008584
# Name: EdLevel, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Fiji                  1
# Gabon                 1
# Mali                  1
# Saint Lucia           1
# Liechtenstein         1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# split object. apply function. combine object

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 4               5  I used to be a developer by profession, but no...      Yes
# 7               8                     I am a developer by profession      Yes
# 13             14                     I am a developer by profession      Yes
# 16             17                     I am a developer by profession      Yes
# 17             18                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64413       58498                                                NaN      Yes
# 64417       58896                                                NaN      Yes
# 64428       60931                                                NaN      Yes
# 64443       63077                                                NaN      Yes
# 64456       64858                                                NaN      Yes
#
# ...

# %%
filtCUSA = df['Country'] == 'United States'
df.loc[filtCUSA]['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          6183
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       2129
# Some college/university study without earning a degree                                1562
# Associate degree (A.A., A.S., etc.)                                                    571
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     555
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             426
# Primary/elementary school                                                              185
# Professional degree (JD, MD, etc.)                                                      61
# I never completed any formal education                                                  60
# Name: EdLevel, dtype: int64

# %%
country_grp['EdLevel'].value_counts(normalize=True).head(50)
# Out:
# Country              EdLevel
# Afghanistan          Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.450000
#                      I never completed any formal education                                                0.200000
#                      Some college/university study without earning a degree                                0.116667
#                      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.066667
#                      Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.066667
#                      Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.050000
#                      Primary/elementary school                                                             0.033333
#                      Professional degree (JD, MD, etc.)                                                    0.016667
# ...

# %% [markdown]
# Now I do not need to change my filter all the time. Nice

# %%
country_grp['EdLevel'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# EdLevel
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.360082
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.274691
# Some college/university study without earning a degree                                0.137860
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.066872
# Professional degree (JD, MD, etc.)                                                    0.065844
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.040123
# Primary/elementary school                                                             0.025720
# Associate degree (A.A., A.S., etc.)                                                   0.016461
# I never completed any formal education                                                0.012346
# Name: EdLevel, dtype: float64

# %% [markdown]
# but what if i want multiple stuff?

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Russian Federation']
# Out:
# median    28304.000000
# mean      36209.548544
# Name: Russian Federation, dtype: float64

# %%
df.loc[filtCUSA]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 5964

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).head(50)
# Out:
# Country
# Afghanistan                           11
# Albania                               13
# Algeria                               40
# Andorra                                3
# Angola                                 1
# Antigua and Barbuda                    0
# Argentina                            134
# Armenia                               17
# Australia                            524
# Austria                              205
# Azerbaijan                            11
# Bahamas                                1
# Bahrain                                2
# Bangladesh                           179
# Barbados                               2
# Belarus                               40
# Belgium                              173
# Belize                                 2
# Benin                                  3
# Bhutan                                 1
# Bolivia                               10
# Bosnia and Herzegovina                25
# Botswana                               2
# ...

# %% [markdown]
# What % of each country know python?

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Fiji                  1
# Gabon                 1
# Mali                  1
# Saint Lucia           1
# Liechtenstein         1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# ...                 ...                 ...
# Fiji                  1                   0
# Gabon                 1                   1
# Mali                  1                   0
# Saint Lucia           1                   1
# Liechtenstein         1                   0
#
# [183 rows x 2 columns]

# %%
python_df['percentage_python_users'] = python_df['LanguageWorkedWith'] / python_df['Country'] * 100
python_df.head(50)
# Out:
#                     Country  LanguageWorkedWith  percentage_python_users
# United States         12469                5964                47.830620
# India                  8403                2670                31.774366
# United Kingdom         3896                1621                41.606776
# Germany                3890                1712                44.010283
# Canada                 2191                1011                46.143314
# France                 1898                 833                43.888303
# Brazil                 1818                 635                34.928493
# Netherlands            1343                 544                40.506329
# Poland                 1278                 509                39.827856
# Australia              1208                 524                43.377483
# Spain                  1161                 448                38.587425
# Italy                  1117                 422                37.779767
# ...

# %% [markdown]
# now how to export files

# %%
filterIndia = (df['Country'] == 'India')
indiadf = df.loc[filterIndia]
indiadf.head()
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 6             7          I am a developer by profession      Yes   NaN
# 21           22          I am a developer by profession      Yes   NaN
# 57           58          I am a developer by profession      Yes   NaN
# 62           63  I am a student who is learning to code      Yes  21.0
# 147         149          I am a developer by profession      Yes  36.0
#
#     Age1stCode CompFreq   CompTotal  SalaryUSD Country          CurrencyDesc  \
# 6           18  Monthly         NaN        NaN   India  United States dollar
# 21          18  Monthly         NaN        NaN   India          Indian rupee
# 57          22      NaN         NaN        NaN   India          Indian rupee
# 62          17      NaN         NaN        NaN   India                   NaN
# 147         31   Yearly  21000000.0   293196.0   India          Indian rupee
#
#     CurrencySymbol      DatabaseDesireNextYear      DatabaseWorkedWith  \
# ...

# %%
indiadf.to_csv('data/modifiedcsv')

# %%
pip install xlwt openpyxl xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
indiadf.to_excel('data/modified.xlsx')
