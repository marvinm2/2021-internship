# %% [markdown]
# Step 1: Import required packages

# %%
import os
import py4cytoscape as p4c

# %% [markdown]
# Step 2: Make new variable and assign it's value to WikiPathways ID

# %%
WP_ID1 = 'WP5035'

# %% [markdown]
# Step 3: Load as network into Cytoscape using py4cytoscape

# %%
cmd_list = ['wikipathways','import-as-network','id="', WP_ID1,'"']
cmd = " ".join(cmd_list)
p4c.commands.commands_get(cmd)
# Out:
# []

# %% [markdown]
# Step 4: Import additional packages and make an image from the loaded pathway

# %%
import IPython
p4c.export_image(filename='loaded_pathwayimage.png')
p4c.sandbox_get_from('loaded_pathwayimage.png')
from IPython.display import Image
Image('loaded_pathwayimage.png')
